# %%
import pandas as pd

# %%
processes = [
    "Photosynthesis",
    "Digestion",
    "Respiration",
    "Fermentation",
    "Cell division",
    "Metamorphosis",
    "Transpiration",
    "Digestive enzyme synthesis",
    "Protein synthesis",
    "Lipid synthesis",
    "Nucleic acid synthesis",
    "Hormone synthesis",
    "Immune response",
    "Healing",
    "Learning",
    "Memory",
    "Thinking",
    "Decision-making",
    "Problem-solving",
    "Communication",
    "Movement",
    "Sensory perception",
    "Sleep",
    "Aging",
    "Death",
    "Plant growth",
    "Animal development",
    "Reproduction",
    "Parenting",
    "Socialization"]

definitions = [
    "Plants, algae, and some bacteria use photosynthesis to convert light energy into chemical energy.",
    "The body breaks down food into smaller molecules through the process of digestion.",
    "Respiration is the process of converting oxygen and nutrients into energy in the body.",
    "Fermentation occurs when microorganisms convert sugars into alcohol or acids.",
    "Cell division is the process by which a cell becomes two or more daughter cells.",
    "Metamorphosis is the transformation of an animal from one form to another, such as from a larva to an adult.",
    "Transpiration is the loss of water from a plant through its leaves.",
    "The body produces digestive enzymes through the process of enzyme synthesis.",
    "Proteins are synthesized from amino acids in the process of protein synthesis.",
    "Lipid synthesis is the production of lipids from fatty acids and glycerol by the body.",
    "Nucleic acid synthesis involves the body's production of nucleic acids, such as DNA and RNA.",
    "Hormone synthesis is the process by which hormones, which regulate various bodily functions, are synthesized by the body.",
    "The immune response is the body's defense against invading pathogens.",
    "Healing is the repair of damaged tissues by the body.",
    "The brain acquires new knowledge and skills through the process of learning.",
    "Memory is the brain's ability to store and retrieve information.",
    "Thinking is the use of information by the brain to understand and solve problems.",
    "Decision-making is the brain's process of making choices based on information and experiences.",
    "Problem-solving is the analysis of information and the finding of solutions by the brain.",
    "Communication is the exchange of information and ideas between individuals.",
    "Movement is the act of an organism moving from one location to another.",
    "Sensory perception is the processing of information from the environment by an organism through its senses.",
    "Sleep is the state in which the body becomes unconscious and certain functions are shut down.",
    "Aging is the process of physical and biological changes in the body as it grows older.",
    "Death is the end of an organism's life.",
    "Plant growth is the process of increasing in size and developing new tissues and organs.",
    "Animal development is the process of growing and changing from an embryo to an adult.",
    "Reproduction is the process of producing offspring.",
    "Parenting is the process of raising and caring for offspring.",
    "Socialization is the process of learning to function within a society or social group."]

# %%
df = pd.DataFrame(list(zip(processes,definitions)),columns = ["processes","definitions"])

# %%
df["processes"] = df["processes"].apply(lambda s: f"The process of {s}")

# %%
x =  {
  "sentences": [
    {
      "text": "The aurora borealis, also known as the northern lights, is a natural light display in the Earth's sky, predominantly seen in the high-latitude regions.",
      "topic": "aurora borealis",
      "category": "definition"
    },
    {
      "text": "Photosynthesis is the process by which plants, algae, and some bacteria convert light energy into chemical energy.",
      "topic": "photosynthesis",
      "category": "description"
    },
    {
      "text": "Climate change is caused by an increase in greenhouse gases in the atmosphere, which traps more heat from the sun and leads to rising global temperatures.",
      "topic": "climate change",
      "category": "cause and effect"
    },
    {
      "text": "One of the major problems with plastic pollution is that it can take hundreds of years to break down in the environment, and a potential solution is to increase the use of biodegradable materials.",
      "topic": "plastic pollution",
      "category": "problem and solution"
    },
    {
      "text": "While a cat is generally smaller and more agile than a dog, dogs are typically more loyal and easier to train.",
      "topic": "cats and dogs",
      "category": "compare and contrast"
    },
    {
      "text": "Genetic drift is a change in the frequency of a gene variant in a population over time, due to random sampling of individuals to reproduce.",
      "topic": "genetic drift",
      "category": "definition"
    },
    {
      "text": "Aging is the process of becoming older, characterized by changes in physical, mental, and social abilities.",
      "topic": "aging",
      "category": "description"
    },
    {
      "text": "One of the main causes of deforestation is the expansion of agriculture, which leads to the removal of forests to create more land for farming.",
      "topic": "deforestation",
      "category": "cause and effect"
    }]}["sentences"]

# %%
pd.DataFrame(x)
# Out:
#                                                 text              topic  \
# 0  The aurora borealis, also known as the norther...    aurora borealis
# 1  Photosynthesis is the process by which plants,...     photosynthesis
# 2  Climate change is caused by an increase in gre...     climate change
# 3  One of the major problems with plastic polluti...  plastic pollution
# 4  While a cat is generally smaller and more agil...      cats and dogs
# 5  Genetic drift is a change in the frequency of ...      genetic drift
# 6  Aging is the process of becoming older, charac...              aging
# 7  One of the main causes of deforestation is the...      deforestation
#
#                category
# 0            definition
# 1           description
# 2      cause and effect
# 3  problem and solution
# 4  compare and contrast
# 5            definition
# 6           description
# 7      cause and effect

# %%
x += [
    {
      "text": "The fall of the Berlin Wall, which occurred in 1989, marked the end of the Cold War and the reunification of Germany.",
      "topic": "fall of the Berlin Wall",
      "category": "historical recounting"
    },
    {
      "text": "One problem with traffic congestion is that it can lead to increased fuel consumption and emissions, and a potential solution is to invest in public transportation and carpooling initiatives.",
      "topic": "traffic congestion",
      "category": "problem and solution"
    },
    {
      "text": "While a laptop is more portable, a desktop computer is generally more powerful and has a larger display.",
      "topic": "laptops and desktop computers",
      "category": "compare and contrast"
    },
    {
      "text": "The Pyramids of Giza, located in Egypt, are ancient structures built as tombs for the Pharaohs and are known for their massive size and precise construction.",
      "topic": "Pyramids of Giza",
      "category": "description of features"
    },
    {
      "text": "Metamorphosis is the process by which certain animals undergo physical changes during development, such as a caterpillar transforming into a butterfly.",
      "topic": "metamorphosis",
      "category": "definition"
    },
    {
      "text": "The French Revolution, which occurred in the late 18th century, was a significant event in European history that marked the end of the monarchy and the beginning of a democratic government.",
      "topic": "French Revolution",
      "category": "historical recounting"
    },
    {
      "text": "One problem with soil erosion is that it can lead to decreased crop yields and a potential solution is to implement sustainable farming practices and use erosion control measures.",
      "topic": "soil erosion",
      "category": "problem and solution"
    }]

# %%
pd.DataFrame(x)
# Out:
#                                                  text  \
# 0   The aurora borealis, also known as the norther...
# 1   Photosynthesis is the process by which plants,...
# 2   Climate change is caused by an increase in gre...
# 3   One of the major problems with plastic polluti...
# 4   While a cat is generally smaller and more agil...
# 5   Genetic drift is a change in the frequency of ...
# 6   Aging is the process of becoming older, charac...
# 7   One of the main causes of deforestation is the...
# 8   The fall of the Berlin Wall, which occurred in...
# 9   One problem with traffic congestion is that it...
# 10  While a laptop is more portable, a desktop com...
# 11  The Pyramids of Giza, located in Egypt, are an...
# 12  Metamorphosis is the process by which certain ...
# 13  The French Revolution, which occurred in the l...
# 14  One problem with soil erosion is that it can l...
#
#                             topic                 category
# ...
